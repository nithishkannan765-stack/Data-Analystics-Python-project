# %% [markdown]
# <a href="https://colab.research.google.com/github/nithishkannan765-stack/Data-Analystics-Python-project/blob/main/DAY2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {
        "emp_nm":["Nithish","Uma"],
        "emp_sal":[15000,12000]
  }
df = pd.DataFrame(data)
df.rename(columns = {
  "emp_nm":"Employee Name",
  "emp_sal":"Employee Salary"
},inplace = True)
print(df)
# Out:
#   Employee Name  Employee Salary
# 0       Nithish            15000
# 1           Uma            12000
