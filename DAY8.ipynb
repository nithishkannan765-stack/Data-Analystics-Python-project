# %% [markdown]
# <a href="https://colab.research.google.com/github/nithishkannan765-stack/Data-Analystics-Python-project/blob/main/DAY8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Data = {
 "ID": [2524127032],
"Name": ["Nithish kannan.U"],
"Fees": [1015]
}
df = pd.DataFrame(Data)
print(df)
# Out:
#            ID              Name  Fees
# 0  2524127032  Nithish kannan.U  1015

# %%
Data = {
"Name": ["Nithish","Karthick","siva"],
"Sales": [10500,None,45000]
}
df = pd.DataFrame(Data)
print(df)
# Out:
#        Name    Sales
# 0   Nithish  10500.0
# 1  Karthick      NaN
# 2      siva  45000.0
