# %% [markdown]
# <a href="https://colab.research.google.com/github/nithishkannan765-stack/Data-Analystics-Python-project/blob/main/DAY9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
employees = {
"Emp_ID" : [1001,1002,1003],
"Name" : ["Nithish","siva","karthi"],
"Department" : ["IT","HR","IT"],
"Salary" : [10000,15000,18000],
"Experience" : [3,4,3]
}
df = pd.DataFrame(employees)
print("Employee Dataset")
print(df)
print("\nAverage Salary")
print(df["Salary"].mean())
print("\nHighest Salary")
print(df["Salary"].max())
# Out:
# Employee Dataset
#    Emp_ID     Name Department  Salary  Experience
# 0    1001  Nithish         IT   10000           3
# 1    1002     siva         HR   15000           4
# 2    1003   karthi         IT   18000           3
#
# Average Salary
# 14333.333333333334
#
# Highest Salary
# 18000
