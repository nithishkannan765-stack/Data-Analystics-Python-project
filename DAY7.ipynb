# %% [markdown]
# <a href="https://colab.research.google.com/github/nithishkannan765-stack/Data-Analystics-Python-project/blob/main/DAY7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
scores=[85,67,54,95,37]
total=sum(scores)
average=total/len(scores)
highest=max(scores)
lowest=min(scores)

print("Total Score:",total)
print("Average Score:",average)
print("Highest Score:",highest)
print("Lowest Score:",lowest)
# Out:
# Total Score: 338
# Average Score: 67.6
# Highest Score: 95
# Lowest Score: 37

# %%
import numpy as np
lower_score = np.array([15])
high_score = np.array([65])
print(f"{lower_score} student lower score")
print(f"{high_score} student high score")
# Out:
# [15] student lower score
# [65] student high score
